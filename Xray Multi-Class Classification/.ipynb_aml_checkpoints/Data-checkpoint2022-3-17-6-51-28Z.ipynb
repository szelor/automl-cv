# %%
# %pip install kaggle --upgrade split-folders

# %%
from azureml.core import Workspace, Dataset, Experiment

ws = Workspace.from_config()

# %%
# Export Kaggle configuration variables
# %env KAGGLE_USERNAME=szelor
# %env KAGGLE_KEY=21cd02df9ad71ca909694a3733b5b22d
# Out:
# env: KAGGLE_USERNAME=szelor
# env: KAGGLE_KEY=21cd02df9ad71ca909694a3733b5b22d

# %%
# Download the Pneumonia dataset. ISSUE: Requires Python 3.6 AzureML kernel which is not available in newer Compute Instances
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia -p ./datafile
# Out:
# Downloading chest-xray-pneumonia.zip to ./datafile
# 100%|███████████████████████████████████████| 2.29G/2.29G [00:19<00:00, 310MB/s]
# 100%|██████████████████████████████████████| 2.29G/2.29G [00:35<00:00, 69.9MB/s]
# unzip:  cannot find or open ./chest-xray-pneumonia.zip, ./chest-xray-pneumonia.zip.zip or ./chest-xray-pneumonia.zip.ZIP.

# %%
# !unzip -q ./datafile/chest-xray-pneumonia.zip -d ./files
# Out:
# ^C

# %%
import json
import os
src = "./files/chest_xray/__MACOSX/chest_xray/test/"
train_validation_ratio = 20

# Retrieving default datastore that got automatically created when we setup a workspace
workspaceblobstore = ws.get_default_datastore().name

# Path to the training and validation files
train_annotations_file = os.path.join(src, "train_annotations.jsonl")
validation_annotations_file = os.path.join(src, "validation_annotations.jsonl")

# sample json line dictionary
json_line_sample = {
    "image_url": "AmlDatastore://"
    + workspaceblobstore
    + "/"
    + os.path.basename(os.path.dirname(src)),
    "label": "",
}

index = 0
# Scan each sub directary and generate jsonl line
with open(train_annotations_file, "w") as train_f:
    with open(validation_annotations_file, "w") as validation_f:
        for className in os.listdir(src):
            subDir = src + className
            if not os.path.isdir(subDir):
                continue
            # Scan each sub directary
            print("Parsing " + subDir)
            for image in os.listdir(subDir):
                json_line = dict(json_line_sample)
                json_line["image_url"] += f"/{className}/{image}"
                json_line["label"] = className

                if index % train_validation_ratio == 0:
                    # validation annotation
                    validation_f.write(json.dumps(json_line) + "\n")
                else:
                    # train annotation
                    train_f.write(json.dumps(json_line) + "\n")
                index += 1
# Out:
# Parsing ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL
# Parsing ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir="./files/chest_xray/__MACOSX/chest_xray/test/", target_path="pneumoniaObjects")
# Out:
# Uploading an estimated of 637 files
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/.amlignore
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/.amlignore, 1 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/.amlignore.amltmp
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/.amlignore.amltmp, 2 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/._.DS_Store
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/._.DS_Store, 3 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/._NORMAL
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/._NORMAL, 4 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/._PNEUMONIA
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/._PNEUMONIA, 5 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/train_annotations.jsonl
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/train_annotations.jsonl, 6 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/train_annotations.jsonl.amltmp
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/train_annotations.jsonl.amltmp, 7 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/validation_annotations.jsonl
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/validation_annotations.jsonl, 8 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/validation_annotations.jsonl.amltmp
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/validation_annotations.jsonl.amltmp, 9 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/.amlignore
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/.amlignore, 10 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/.amlignore.amltmp
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/.amlignore.amltmp, 11 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0001-0001.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0001-0001.jpeg, 12 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0003-0001.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0003-0001.jpeg, 13 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0005-0001.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0005-0001.jpeg, 14 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0006-0001.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0006-0001.jpeg, 15 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0007-0001.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0007-0001.jpeg, 16 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0009-0001.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0009-0001.jpeg, 17 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0010-0001.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0010-0001.jpeg, 18 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0011-0001-0001.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-
files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person91_bacteria_446.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person91_bacteria_446.jpeg, 617 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person91_bacteria_447.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person91_bacteria_447.jpeg, 618 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person88_bacteria_439.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person88_bacteria_439.jpeg, 619 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person89_bacteria_440.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person89_bacteria_440.jpeg, 620 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person90_bacteria_442.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person90_bacteria_442.jpeg, 621 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person91_bacteria_448.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person91_bacteria_448.jpeg, 622 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person91_bacteria_449.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person91_bacteria_449.jpeg, 623 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person92_bacteria_450.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person92_bacteria_450.jpeg, 624 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person92_bacteria_451.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person92_bacteria_451.jpeg, 625 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person93_bacteria_453.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person93_bacteria_453.jpeg, 626 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person93_bacteria_454.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person93_bacteria_454.jpeg, 627 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person94_bacteria_456.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person94_bacteria_456.jpeg, 628 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person94_bacteria_457.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person94_bacteria_457.jpeg, 629 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person94_bacteria_458.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person94_bacteria_458.jpeg, 630 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person95_bacteria_463.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person95_bacteria_463.jpeg, 631 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person96_bacteria_464.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person96_bacteria_464.jpeg, 632 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person96_bacteria_465.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person96_bacteria_465.jpeg, 633 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person96_bacteria_466.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person96_bacteria_466.jpeg, 634 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person97_bacteria_468.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person97_bacteria_468.jpeg, 635 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person99_bacteria_473.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person99_bacteria_473.jpeg, 636 files out of an estimated total of 637
# Uploading ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person99_bacteria_474.jpeg
# Uploaded ./files/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA/._person99_bacteria_474.jpeg, 637 files out of an estimated total of 637
# Uploaded 637 files
# $AZUREML_DATAREFERENCE_65c8491d51cf4450a9e3692df579c064

# %%
from azureml.core import Dataset
from azureml.data import DataType

# get existing training dataset
training_dataset_name = "pneumoniaTrainingDataset"
if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print("Found the training dataset", training_dataset_name)
else:
    # create training dataset 
    training_dataset = Dataset.Tabular.from_json_lines_files(
        path=ds.path("pneumoniaObjects/train_annotations.jsonl"),
        set_column_types={"image_url": DataType.to_stream(ds.workspace)},
    )
    training_dataset = training_dataset.register(
        workspace=ws, name=training_dataset_name
    )
# get existing validation dataset
validation_dataset_name = "pneumoniaValidationDataset"
if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print("Found the validation dataset", validation_dataset_name)
else:
    # create validation dataset
    validation_dataset = Dataset.Tabular.from_json_lines_files(
        path=ds.path("pneumoniaObjects/validation_annotations.jsonl"),
        set_column_types={"image_url": DataType.to_stream(ds.workspace)},
    )
    validation_dataset = validation_dataset.register(
        workspace=ws, name=validation_dataset_name
    )
print("Training dataset name: " + training_dataset.name)
print("Validation dataset name: " + validation_dataset.name)
# Out:
# Training dataset name: pneumoniaTrainingDataset
# Validation dataset name: pneumoniaValidationDataset

# %%
training_dataset.to_pandas_dataframe()
# Out:
#                                              image_url      label
# 0    workspaceblobstore/test/NORMAL/._IM-0001-0001....     NORMAL
# 1    workspaceblobstore/test/NORMAL/._IM-0003-0001....     NORMAL
# 2    workspaceblobstore/test/NORMAL/._IM-0005-0001....     NORMAL
# 3    workspaceblobstore/test/NORMAL/._IM-0006-0001....     NORMAL
# 4    workspaceblobstore/test/NORMAL/._IM-0007-0001....     NORMAL
# ..                                                 ...        ...
# 588  workspaceblobstore/test/PNEUMONIA/._person96_b...  PNEUMONIA
# 589  workspaceblobstore/test/PNEUMONIA/._person96_b...  PNEUMONIA
# 590  workspaceblobstore/test/PNEUMONIA/._person97_b...  PNEUMONIA
# 591  workspaceblobstore/test/PNEUMONIA/._person99_b...  PNEUMONIA
# 592  workspaceblobstore/test/PNEUMONIA/._person99_b...  PNEUMONIA
#
# [593 rows x 2 columns]
